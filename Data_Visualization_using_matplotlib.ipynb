# %%
import matplotlib.pyplot as plt
x=[2,4,6,8,10]
y= [1,2,3,4,5]

# %%
x
# Out:
# [2, 4, 6, 8, 10]

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.plot(x,y)

# %%
x=[23,-10,15,-4]
y=[5,7,-9,4]

# %%
x
# Out:
# [23, -10, 15, -4]

# %%
y
# Out:
# [5, 7, -9, 4]

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot value
plt.plot(x,y)

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.plot(x,y,linestyle='dotted')

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.plot(x,y,linestyle='dotted',color='r',marker='o')

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.plot(x,y,linestyle='dotted',color='b',marker='+',ms=25)

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.scatter(x,y,marker='+')

# %%
#x Lable
plt.xlabel("sales")
#y Lable
plt.ylabel("Profit")
#plot title
plt.title("sales vs Profit")
#plot values
plt.scatter(x,y,marker='+')
plt.bar(y,x)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # subplot

# %%
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([40,50,60,70,80,90])

# %%
plt.plot(a,b)

# %%
plt.plot(a,c)

# %%
plt.plot(a,d)

# %%
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([45,59,68,74,84,92])

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(c,d)

# %%
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(c,d)

#plot1
plt.subplot(2,2,1)
plt.plot(b,c)

#plot2
plt.subplot(2,2,4)
plt.plot(a,c)

# %%
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

# %%
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(c,d)

# %%
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

# %%
#plot1
plt.subplot(3,2,3)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,2)
plt.plot(c,d,color='g')

#plot1
plt.subplot(3,2,1)
plt.plot(b,c,color='b')

#plot2
plt.subplot(3,2,4)
plt.plot(a,c,color='y')

# %%
#plot1
plt.subplot(3,2,3)
plt.plot(a,d)

#plot2
plt.subplot(3,2,2)
plt.plot(c,d)

# %%
#plot1
plt.subplot(3,2,1)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,4)
plt.plot(c,d,color='g')

#plot3
plt.subplot(3,2,5)
plt.plot(b,c,color='b')

#plot4
plt.subplot(3,2,6)
plt.plot(a,c,color='y')

# %%
#plot1
plt.subplot(3,2,1)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,4)
plt.plot(c,d,color='g')

#plot3
plt.subplot(3,2,5)
plt.plot(b,c,color='b')

#plot4
plt.subplot(3,2,6)
plt.plot(a,c,color='y')

#plot5
plt.subplot(3,2,2)
plt.plot(a,b,color='w')

#plot6
plt.subplot(3,2,3)
plt.plot(b,d,color='y')

# %% [markdown]
# # Histogram

# %%
data1=np.random.normal(150,10,250)

# %%
data1
# Out:
# array([138.56378958, 148.90900375, 156.89251632, 161.78716364,
#        149.07253925, 161.74387149, 154.78476534, 155.33034702,
#        168.35265259, 167.94674754, 155.84842294, 155.60849767,
#        156.67138726, 148.94322867, 143.41992751, 166.03152249,
#        139.5221052 , 164.13193968, 143.85839476, 146.60106284,
#        146.81470578, 139.91715847, 154.86589628, 143.75852525,
#        153.9728739 , 155.24634858, 153.00820661, 136.15564453,
#        143.02402168, 156.0966982 , 149.47057705, 151.24545377,
#        140.75252796, 152.39807412, 140.13526397, 156.0421228 ,
#        144.09410481, 162.74344655, 156.34407721, 160.19307056,
#        150.92628817, 158.86852483, 154.38532186, 146.23753633,
#        164.62492284, 142.92615565, 140.2218738 , 163.14371412,
#        135.07328989, 154.61695928, 142.33859074, 149.18699629,
#        140.25494697, 152.78377247, 146.44432522, 144.99638645,
#        160.03616732, 147.78426143, 140.87919422, 142.59896999,
# ...

# %%
len(data1)
# Out:
# 250

# %%
data=np.array([44,55,55,77,88,99])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data,bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Creat numpy array for 18 students containing marks of
# #and create histrogram with bin size 10

# %%
import numpy as np
data=np.random.normal([40,45,46,85,42,46,49,43,50,55])
plt.hist(data,bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data
# Out:
# array([39.25652809, 45.09049627, 45.21956279, 85.67221411, 42.81471621,
#        45.65263749, 48.87149027, 42.8414237 , 51.01982761, 52.51826456])

# %%
#pie chart

#create dataset
cars=['audi','BMW','tata','honda']
sale=[88,100,89,610]

#creat pie chart
plt.pie(sale,labels=cars)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
